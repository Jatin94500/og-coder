# %% [markdown]
# # 🌞 Space Weather Monitoring & Solar Storm Risk Prediction System
#
# ## Complete Implementation for Google Colab
#
# This notebook implements a comprehensive system for:
# - ☀️ Real-time space weather data collection
# - 🔥 Solar flare prediction
# - 🌍 Geomagnetic storm forecasting
# - 🛰️ Satellite and communication system risk assessment
# - 📊 Interactive visualization dashboard
#
# **Run all cells in sequence to build and test the complete system!**

# %% [markdown]
# ## 📦 Step 1: Install Dependencies

# %%
# !pip install -q requests pandas numpy matplotlib seaborn scikit-learn tensorflow xgboost lightgbm plotly
print("✓ All packages installed successfully!")

# %% [markdown]
# ## 📚 Step 2: Import Libraries

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime, timedelta
import json
import warnings
warnings.filterwarnings('ignore')

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, r2_score, accuracy_score
import xgboost as xgb
import lightgbm as lgb

# Deep Learning
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

print("✓ All libraries imported successfully")
